# %%
# %cd /content
# !git clone -b boundary --recursive https://github.com/david20041024/CARD
# Out:
# /content
# Cloning into 'CARD'...
# remote: Enumerating objects: 1852, done.
# remote: Counting objects: 100% (1852/1852), done.
# remote: Compressing objects: 100% (843/843), done.
# remote: Total 1852 (delta 1018), reused 1823 (delta 989), pack-reused 0 (from 0)
# Receiving objects: 100% (1852/1852), 12.37 MiB | 30.17 MiB/s, done.
# Resolving deltas: 100% (1018/1018), done.

# %%
import os
os.environ['CUDA_HOME'] = '/usr/local/cuda' #ensure that the CUDA path is correct
# !pip install -q plyfile
# !pip install ninja
# !pip install torch torchvision
# !pip install numpy scipy tqdm
# !pip install open3d
# !pip install tqdm torchvision scikit-learn
# !pip install scikit-image
# !pip install scikit-video
# !pip install cmapy
# !pip install configargparse
# !pip install h5py
# !pip install tensorboard tensorboardX
# %cd /content/CARD/submodules/simple-knn
# !python setup.py install
# %cd /content/CARD/submodules/diff-surfel-rasterization
# !python setup.py install
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cmapy: filename=cmapy-0.6.6-py3-none-any.whl size=3938 sha256=15baafc9fddcaccf6658bb21f5d2700d185e16d7b245be9c7faabbd132fdc3a5
#   Stored in directory: /root/.cache/pip/wheels/8f/8b/45/9402d586dc9795ca029a77c5c8b9f5e3e16b38e7c682883f34
# Successfully built cmapy
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.5 MB/s eta 0:00:00
# ...
# /content/CARD/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/CARD/
# !python boundary.py -s /content/drive/MyDrive/scan55 --start_checkpoint /content/drive/MyDrive/chkpnt30000.pth --sdf_path /content/drive/MyDrive/scan55.pth --xyz_mesh /content/drive/MyDrive/scan55.xyz --xyz_nonboundary /content/drive/MyDrive/scan55_front.xyz
# Out:
# /content/CARD
# 2026-05-24 18:11:21.923600: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Optimizing
# Output folder: ./output/c195fa5a-e [24/05 18:11:27]
# Reading camera 49/49 [24/05 18:11:27]
# Loading Training Cameras [24/05 18:11:27]
# Loading Test Cameras [24/05 18:11:32]
# Number of points at initialisation :  46774 [24/05 18:11:32]
# Training progress:   2% 100/5999 [00:21<21:28,  4.58it/s, Loss=0.06079, distort=0.00000, normal=0.00330, Points=465481]88865 boundary gaussians found out of 465481 [24/05 18:11:56]
# Training progress:   3% 200/5999 [00:43<21:21,  4.52it/s, Loss=0.05572, distort=0.00000, normal=0.00292, Points=447693]94701 boundary gaussians found out of 447693 [24/05 18:12:18]
# ...

# %%
# !pip install mediapy trimesh
# !python scripts/dtu_eval.py --dtu /content/drive/MyDrive --DTU_Official /content/drive/MyDrive/scan55_dtu --output_path /content/CARD/output --skip_training
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/diff_surfel_rasterization-0.0.1-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
# python render.py --iteration 30000 -s /content/drive/MyDrive/scan55 -m/content/CARD/output/scan55 --quiet --skip_train --depth_ratio 1.0 --num_cluster 1 --voxel_size 0.004 --sdf_trunc 0.016 --depth_trunc 3.0
# Looking for config file in /content/CARD/output/scan55/cfg_args
# Config file found: /content/CARD/output/scan55/cfg_args
# Rendering /content/CARD/output/scan55
# ...

# %%
# !zip -r scan55.zip /content/CARD/output/scan55
# Out:
#   adding: content/CARD/output/489152a7-c/ (stored 0%)
#   adding: content/CARD/output/489152a7-c/cfg_args (deflated 24%)
#   adding: content/CARD/output/489152a7-c/input.ply (deflated 45%)
#   adding: content/CARD/output/489152a7-c/point_cloud/ (stored 0%)
#   adding: content/CARD/output/489152a7-c/point_cloud/iteration_2500/ (stored 0%)
#   adding: content/CARD/output/489152a7-c/point_cloud/iteration_2500/point_cloud.ply (deflated 11%)
#   adding: content/CARD/output/489152a7-c/point_cloud/iteration_5000/ (stored 0%)
#   adding: content/CARD/output/489152a7-c/point_cloud/iteration_5000/point_cloud.ply (deflated 11%)
#   adding: content/CARD/output/489152a7-c/events.out.tfevents.1779249085.85ce0185daba.67053.0 (deflated 2%)
#   adding: content/CARD/output/489152a7-c/cameras.json (deflated 66%)
