# %%
# %cd /content
# !git clone -b main --recursive https://github.com/david20041024/BAND-and-REBORN-2DGS
# Out:
# /content
# Cloning into 'REBORN-2DGS'...
# remote: Enumerating objects: 1909, done.
# remote: Counting objects: 100% (1909/1909), done.
# remote: Compressing objects: 100% (881/881), done.
# remote: Total 1909 (delta 1057), reused 1857 (delta 1005), pack-reused 0 (from 0)
# Receiving objects: 100% (1909/1909), 12.39 MiB | 15.70 MiB/s, done.
# Resolving deltas: 100% (1057/1057), done.

# %%
import os
os.environ['CUDA_HOME'] = '/usr/local/cuda' #ensure that the CUDA path is correct
# !pip install -q plyfile
# !pip install ninja
# !pip install torch torchvision
# !pip install numpy scipy tqdm
# !pip install open3d
# !pip install tqdm torchvision scikit-learn
# !pip install scikit-image
# !pip install scikit-video
# !pip install cmapy
# !pip install configargparse
# !pip install h5py
# !pip install tensorboard tensorboardX
# %cd /content/BAND-and-REBORN-2DGS/submodules/simple-knn
# !python setup.py install
# %cd /content/BAND-and-REBORN-2DGS/submodules/diff-surfel-rasterization
# !python setup.py install
# Out:
# ...
# /content/REBORN-2DGS/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/BAND-and-REBORN-2DGS/
# !python boundary.py -s /content/drive/MyDrive/scan106 --start_checkpoint /content/drive/MyDrive/chkpnt30000.pth --xyz_mesh /content/drive/MyDrive/scan106.xyz --xyz_nonboundary /content/drive/MyDrive/scan106_front.xyz
# Out:
# /content/REBORN-2DGS
# 2026-06-12 12:21:23.843070: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Optimizing
# Output folder: ./output/0d0c2aec-c [12/06 12:21:28]
# Reading camera 64/64 [12/06 12:22:05]
# Loading Training Cameras [12/06 12:22:06]
# Loading Test Cameras [12/06 12:22:12]
# Number of points at initialisation :  46336 [12/06 12:22:13]
# 13344 boundary gaussians found out of 133539 [12/06 12:22:25]
# Training progress:  19% 1500/7999 [04:21<19:31,  5.55it/s, Loss=0.02913, distort=0.00000, normal=0.00179, Points=160921]
# [ITER 1500] Evaluating train: L1 0.011613376811146736 PSNR 35.56018486022949 [12/06 12:27:14]
#
# [ITER 1500] Saving Gaussians [12/06 12:27:14]
# ...

# %%
# !pip install mediapy trimesh
# %cd /content/BAND-and-REBORN-2DGS/
# !python scripts/dtu_eval.py --dtu /content/drive/MyDrive --DTU_Official /content/drive/MyDrive/scan55_dtu --output_path /content/REBORN-2DGS/output --skip_training
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/diff_surfel_rasterization-0.0.1-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 20.0 MB/s eta 0:00:00
# ...
# /content/REBORN-2DGS
# python render.py --iteration 30000 -s /content/drive/MyDrive/scan106 -m/content/REBORN-2DGS/output/scan106 --quiet --skip_train --depth_ratio 1.0 --num_cluster 1 --voxel_size 0.004 --sdf_trunc 0.016 --depth_trunc 3.0
# ...

# %%
# !zip -r scan122_new.zip /content/BAND-and-REBORN-2DGS/output/scan122
# Out:
#   adding: content/BAND-2DGS/output/scan122/ (stored 0%)
#   adding: content/BAND-2DGS/output/scan122/chkpnt7000.pth (deflated 12%)
#   adding: content/BAND-2DGS/output/scan122/cameras.json (deflated 66%)
#   adding: content/BAND-2DGS/output/scan122/train/ (stored 0%)
#   adding: content/BAND-2DGS/output/scan122/train/ours_30000/ (stored 0%)
#   adding: content/BAND-2DGS/output/scan122/train/ours_30000/fuse_post.ply (deflated 61%)
#   adding: content/BAND-2DGS/output/scan122/train/ours_30000/fuse.ply (deflated 60%)
#   adding: content/BAND-2DGS/output/scan122/chkpnt30000.pth (deflated 15%)
#   adding: content/BAND-2DGS/output/scan122/events.out.tfevents.1780487073.1932889416db.3346.0 (deflated 76%)
#   adding: content/BAND-2DGS/output/scan122/cfg_args (deflated 29%)
#   adding: content/BAND-2DGS/output/scan122/point_cloud/ (stored 0%)
#   adding: content/BAND-2DGS/output/scan122/point_cloud/iteration_30000/ (stored 0%)
# ...
